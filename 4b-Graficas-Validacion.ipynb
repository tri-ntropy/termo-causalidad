# %% [markdown]
# ## Importación de bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Opciones de graficación
# Estética de las gráficas

# %%
sns.set_style("darkgrid")                  
sns.set_context("paper", font_scale = 2.4)  # Tamaño de fuente en el contexto de un "paper"

# %%
def graficar_simple(experimento, sentido):
    global t_pasos, promedio
    tiempo = t_pasos
    x_marcas = [1, 10, 20, 30, 40, 50, 60, 70]
    etiqueta_tiempo = "$\\nu$"
    etiquetas_sentido = {"xy" : "$ \\mathrm{STE}_{X \\rightarrow Y} $",
                         "yx" : "$ \\mathrm{STE}_{Y \\rightarrow X} $"}
    plt.figure(figsize = (10, 6))
    plt.plot(tiempo, promedio[experimento][sentido][1 :], "o--")
    plt.xlim(tiempo.min(), tiempo.max())
    plt.xticks(x_marcas)
    plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0), useMathText = True)
    plt.xlabel(etiqueta_tiempo)
    plt.ylabel(etiquetas_sentido[sentido])
    plt.savefig("graficas/entropia_validacion/" + experimento + "_" + sentido + "_null.pdf", bbox_inches = "tight")
    plt.show()

# %%
def graficar_diferencia(experimento, diferencia, por_pasos = True):
    global t_pasos, promedio
    tiempo = t_pasos
    x_marcas = [1, 10, 20, 30, 40, 50, 60, 70]
    etiqueta_tiempo = "$\\nu$"
    etiquetas_sentido = {"xy-yx" : "$ \\mathrm{STE}_{X \\rightarrow Y} - \\mathrm{STE}_{Y \\rightarrow X} $",
                         "yx-xy" : "$ \\mathrm{STE}_{Y \\rightarrow X} - \\mathrm{STE}_{X \\rightarrow Y} $"}
    plt.figure(figsize = (10, 6))
    plt.plot(tiempo, promedio_diferencias[experimento][diferencia][1 :], "o--")
    plt.xlim(tiempo.min(), tiempo.max())
    plt.xticks(x_marcas)
    plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0), useMathText = True)
    plt.xlabel(etiqueta_tiempo)
    plt.ylabel(etiquetas_sentido[diferencia])
    plt.savefig("graficas/entropia_validacion/" + experimento + "_" + diferencia + "_null.pdf", bbox_inches = "tight")
    plt.show()

# %% [markdown]
# ## Lista de archivos

# %%
ruta = "datos/caracter_entropia_validacion/"

# %% [markdown]
# ## Tiempo

# %%
t = np.loadtxt("datos/base/tiempo_ets.csv")[: 70]
t_pasos = np.loadtxt("datos/base/pasos_ets.csv")[: 70]

# %% [markdown]
# ## Inicialización de "metadatos"

# %%
sentidos = ["xy", "yx"]
diferencias = ["xy-yx", "yx-xy"]
experimentos = ["00", "01", "02", "03", "04", "05"]

# %% [markdown]
# ## Inicialización de diccionarios

# %%
error = {}
promedio = {}

error_diferencias = {}
promedio_diferencias = {}

# %% [markdown]
# ## Lectura y organización de datos respecto a sus "metadatos"

# %%
for ex in experimentos:
    error[ex] = {}
    promedio[ex] = {}
    for sen in sentidos:
        error[ex][sen] = np.loadtxt(ruta + "error_" + ex + "_" + sen + "_null.csv")
        promedio[ex][sen] = np.loadtxt(ruta + "promedio_" + ex + "_" + sen + "_null.csv")
    
    error_diferencias[ex] = {}
    promedio_diferencias[ex] = {}
    for dif in diferencias:
        error_diferencias[ex][dif] = np.loadtxt(ruta + "error_" + ex + "_" + dif + ".csv")
        promedio_diferencias[ex][dif] = np.loadtxt(ruta + "promedio_" + ex + "_" + dif + ".csv")

# %% [markdown]
# ## Proceso de graficación

# %%
for exp in experimentos:
    for sen in sentidos:
        print("Experimento: ", exp)
        print("Sentido: ", sen)
        graficar_simple(exp, sen)
    for dif in diferencias:
        print("Experimento: ", exp)
        print("Diferencia: ", dif)
        graficar_diferencia(exp, dif)
# Out:
# Experimento:  00
# Sentido:  xy
# Experimento:  00
# Sentido:  yx
# Experimento:  00
# Diferencia:  xy-yx
# Experimento:  00
# Diferencia:  yx-xy
# Experimento:  01
# Sentido:  xy
# Experimento:  01
# Sentido:  yx
# Experimento:  01
# Diferencia:  xy-yx
# Experimento:  01
# Diferencia:  yx-xy
# Experimento:  02
# Sentido:  xy
# Experimento:  02
# Sentido:  yx
# Experimento:  02
# Diferencia:  xy-yx
# Experimento:  02
# Diferencia:  yx-xy
# Experimento:  03
# Sentido:  xy
# Experimento:  03
# Sentido:  yx
# Experimento:  03
# Diferencia:  xy-yx
# Experimento:  03
# Diferencia:  yx-xy
# Experimento:  04
# Sentido:  xy
# Experimento:  04
# Sentido:  yx
# Experimento:  04
# Diferencia:  xy-yx
# Experimento:  04
# Diferencia:  yx-xy
# Experimento:  05
# Sentido:  xy
# Experimento:  05
# Sentido:  yx
# Experimento:  05
# Diferencia:  xy-yx
# Experimento:  05
# Diferencia:  yx-xy
