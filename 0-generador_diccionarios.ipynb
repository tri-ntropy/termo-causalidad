# %% [markdown]
# # Prueba de diccionarios: tamaños de ventana $m = 3$ y $m = 4$

# %% [markdown]
# ### Importación de bibliotecas y módulos

# %%
import numpy as np
import modulo_ets as mets
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Opciones de graficación
# Estética de las gráficas

# %%
sns.set_style("darkgrid")
sns.set_context("paper", font_scale = 1.5)

# %% [markdown]
# ## Función para imprimir las series y diccionarios de símbolos

# %%
def imprimir(serie, ventana):
    serie_simbolos = mets.simbolizar(serie, m = ventana)
    dicc_simbolos = np.sort(np.array(list(set(serie_simbolos))))
    print("Tamaño de la serie: \n", serie_simbolos.size)
    print("Serie: \n", serie_simbolos)
    print("Tamaño del diccionario: \n", dicc_simbolos.size)
    print("Diccionario: \n", dicc_simbolos)

# %% [markdown]
# ## Dominio temporal
#
# El tiempo en el que se pretende realizar la "simulación"

# %%
n = 83
t = np.linspace(0, 1, n)

# %% [markdown]
# ## Simulación

# %%
# Simulación de variable continua
a = np.random.normal(0, 0.4, size = n)
a[a > 0.8] = 1.0
a[a < -0.8] = -1.0
# Simulación de una variable discreta: dado de seis caras
b = np.random.randint(1, 7, size = n)
b[16: 20] = 4
b[26: 30] = np.linspace(2, 5, 4)
b[36: 40] = np.linspace(5, 2, 4)

# %% [markdown]
# ## Gráfica de la variable continua

# %%
plt.figure(figsize = (20, 5))
plt.ylabel("$\\mathbf{X}$")
plt.xlabel("$t$")
plt.plot(t, a, "o--")
plt.savefig("graficas/diccionarios/ruido_blanco.pdf", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Simulación del dado

# %%
plt.figure(figsize = (20, 5))
plt.ylabel("$\\mathbf{Y}$")
plt.xlabel("$t$")
plt.plot(t, b, "o--")
plt.savefig("graficas/diccionarios/dado_seiscaras.pdf", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Serie y diccionario de simbolos de la variable continua con $m = 3$

# %%
imprimir(a, 3)
# Out:
# Tamaño de la serie:
#  81
# Serie:
#  ['132' '213' '231' '312' '123' '231' '312' '123' '123' '231' '312' '123'
#  '231' '321' '312' '231' '213' '132' '321' '321' '213' '132' '213' '123'
#  '231' '321' '213' '231' '312' '132' '321' '321' '213' '132' '213' '132'
#  '312' '231' '321' '321' '321' '213' '132' '312' '132' '312' '123' '231'
#  '321' '213' '231' '213' '132' '312' '231' '321' '213' '123' '132' '213'
#  '132' '321' '213' '231' '312' '123' '123' '132' '213' '231' '312' '123'
#  '231' '312' '123' '123' '132' '321' '213' '132' '321']
# Tamaño del diccionario:
#  6
# Diccionario:
#  ['123' '132' '213' '231' '312' '321']

# %% [markdown]
# ## Serie y diccionario de simbolos de la variable continua con $m = 4$

# %%
imprimir(a, 4)
# Out:
# Tamaño de la serie:
#  80
# Serie:
#  ['1324' '3241' '2413' '4123' '2341' '3412' '4123' '1234' '1342' '3412'
#  '4123' '1342' '3421' '4312' '4231' '2314' '2143' '2431' '4321' '3214'
#  '3142' '1324' '2134' '2341' '3421' '4213' '3241' '2413' '4132' '1432'
#  '4321' '3214' '2143' '1324' '3142' '1423' '4231' '3421' '4321' '4321'
#  '3214' '3142' '1423' '4132' '1423' '4123' '1342' '3421' '3214' '3241'
#  '2314' '3142' '1423' '4231' '3421' '4213' '2134' '1243' '1324' '2143'
#  '2431' '3214' '3241' '3412' '4123' '1234' '1243' '1324' '3241' '2413'
#  '4123' '2341' '3412' '4123' '1234' '1243' '2431' '4213' '2143' '1432']
# Tamaño del diccionario:
#  23
# Diccionario:
#  ['1234' '1243' '1324' '1342' '1423' '1432' '2134' '2143' '2314' '2341'
#  '2413' '2431' '3142' '3214' '3241' '3412' '3421' '4123' '4132' '4213'
#  '4231' '4312' '4321']

# %% [markdown]
# ## Serie y diccionario de simbolos del dado con $m = 3$

# %%
imprimir(b, 3)
# Out:
# Tamaño de la serie:
#  81
# Serie:
#  ['123' '231' '312' '123' '123' '121' '212' '132' '211' '111' '112' '122'
#  '221' '212' '132' '211' '111' '111' '111' '221' '321' '321' '211' '112'
#  '132' '312' '123' '123' '231' '312' '121' '213' '121' '312' '123' '121'
#  '321' '321' '321' '213' '132' '213' '231' '212' '132' '321' '211' '112'
#  '123' '121' '213' '231' '321' '213' '132' '321' '213' '132' '321' '321'
#  '212' '121' '321' '211' '112' '122' '111' '221' '321' '211' '112' '122'
#  '221' '312' '231' '212' '123' '231' '312' '123' '122']
# Tamaño del diccionario:
#  13
# Diccionario:
#  ['111' '112' '121' '122' '123' '132' '211' '212' '213' '221' '231' '312'
#  '321']

# %% [markdown]
# ## Serie y diccionario de simbolos del dado con $m = 4$

# %%
imprimir(b, 4)
# Out:
# Tamaño de la serie:
#  80
# Serie:
#  ['1231' '3412' '4123' '1234' '1232' '1212' '3132' '1322' '2111' '1112'
#  '1122' '2331' '2212' '3132' '1322' '2111' '1111' '1111' '2221' '3321'
#  '4321' '3211' '2113' '1132' '1423' '4123' '1234' '2341' '3412' '3121'
#  '1213' '2131' '1312' '3123' '1232' '2321' '4321' '4321' '3214' '2143'
#  '1324' '3241' '2313' '3132' '1321' '3211' '3112' '1123' '1232' '1213'
#  '3241' '3421' '3213' '2143' '1321' '3213' '3142' '1432' '4321' '3212'
#  '2121' '2321' '3211' '2113' '1122' '1222' '2221' '3321' '3211' '2113'
#  '1122' '1332' '3312' '4231' '2313' '2123' '1231' '3412' '4123' '1233']
# Tamaño del diccionario:
#  48
# Diccionario:
#  ['1111' '1112' '1122' '1123' '1132' '1212' '1213' '1222' '1231' '1232'
#  '1233' '1234' '1312' '1321' '1322' '1324' '1332' '1423' '1432' '2111'
#  '2113' '2121' '2123' '2131' '2143' '2212' '2221' '2313' '2321' '2331'
#  '2341' '3112' '3121' '3123' '3132' '3142' '3211' '3212' '3213' '3214'
#  '3241' '3312' '3321' '3412' '3421' '4123' '4231' '4321']
